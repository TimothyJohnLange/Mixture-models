# 0                                                 --Xpvc--         1  0.692478
# 1                                              --Xfiller--         1  0.504600
# 2                                                  --Xfr--         1  0.478605
# 3                                          --Xstabiliser--         1  0.560055
# 4                                                --Xdinp--         1  0.487075
# 5                                                 --Xldh--         1  0.319066
# 6                                                 --Xsph--         1  0.491901
# 7                                        --Xpvc--Xfiller--         2  0.716205
# 8                          --Xpvc--Xfiller--Xpvc*Xfiller--         3  0.726232
# 9                                            --Xpvc--Xfr--         2  0.692503
# 10                                 --Xpvc--Xfr--Xpvc*Xfr--         3  0.692569
# 11                                   --Xpvc--Xstabiliser--         2  0.692538
# 12                 --Xpvc--Xstabiliser--Xpvc*Xstabiliser--         3  0.692656
# 13                                         --Xpvc--Xdinp--         2  0.733353
# 14                             --Xpvc--Xdinp--Xpvc*Xdinp--         3  0.741495
# 15                                          --Xpvc--Xldh--         2  0.726334
# 16                               --Xpvc--Xldh--Xpvc*Xldh--         3  0.733463
# 17                                          --Xpvc--Xsph--         2  0.697381
# 18                               --Xpvc--Xsph--Xpvc*Xsph--         3  0.701485
# 19                                        --Xfiller--Xfr--         2  0.618335
# 20                           --Xfiller--Xfr--Xfiller*Xfr--         3  0.646931
# 21                                --Xfiller--Xstabiliser--         2  0.652645
# 22           --Xfiller--Xstabiliser--Xfiller*Xstabiliser--         3  0.664658
# 23                                      --Xfiller--Xdinp--         2  0.594867
# 24                       --Xfiller--Xdinp--Xfiller*Xdinp--         3  0.635889
# 25                                       --Xfiller--Xldh--         2  0.544974
# 26                         --Xfiller--Xldh--Xfiller*Xldh--         3  0.584749
# 27                                       --Xfiller--Xsph--         2  0.638291
# 28                         --Xfiller--Xsph--Xfiller*Xsph--         3  0.650393
# 29                                    --Xfr--Xstabiliser--         2  0.610584
# ...                                                    ...       ...       ...
# 2350571  --Xpvc--Xfiller--Xfr--Xstabiliser--Xdinp--Xldh...        26  0.921522
# 2350572  --Xpvc--Xfiller--Xfr--Xstabiliser--Xdinp--Xldh...        26  0.920948
# 2350573  --Xpvc--Xfiller--Xfr--Xstabiliser--Xdinp--Xldh...        26  0.919037
# 2350574  --Xpvc--Xfiller--Xfr--Xstabiliser--Xdinp--Xldh...        26  0.921266
# 2350575  --Xpvc--Xfiller--Xfr--Xstabiliser--Xdinp--Xldh...        26  0.915872
# 2350576  --Xpvc--Xfiller--Xfr--Xstabiliser--Xdinp--Xldh...        26  0.922094
# 2350577  --Xpvc--Xfiller--Xfr--Xstabiliser--Xdinp--Xldh...        26  0.920565
# 2350578  --Xpvc--Xfiller--Xfr--Xstabiliser--Xdinp--Xldh...        26  0.919380
# 2350579  --Xpvc--Xfiller--Xfr--Xstabiliser--Xdinp--Xldh...        27  0.920922
# 2350580  --Xpvc--Xfiller--Xfr--Xstabiliser--Xdinp--Xldh...        27  0.923060
# 2350581  --Xpvc--Xfiller--Xfr--Xstabiliser--Xdinp--Xldh...        27  0.906868
# 2350582  --Xpvc--Xfiller--Xfr--Xstabiliser--Xdinp--Xldh...        27  0.921782
# 2350583  --Xpvc--Xfiller--Xfr--Xstabiliser--Xdinp--Xldh...        27  0.923170
# 2350584  --Xpvc--Xfiller--Xfr--Xstabiliser--Xdinp--Xldh...        27  0.921180
# 2350585  --Xpvc--Xfiller--Xfr--Xstabiliser--Xdinp--Xldh...        27  0.918439
# 2350586  --Xpvc--Xfiller--Xfr--Xstabiliser--Xdinp--Xldh...        27  0.922372
# 2350587  --Xpvc--Xfiller--Xfr--Xstabiliser--Xdinp--Xldh...        27  0.915808
# 2350588  --Xpvc--Xfiller--Xfr--Xstabiliser--Xdinp--Xldh...        27  0.922548
# 2350589  --Xpvc--Xfiller--Xfr--Xstabiliser--Xdinp--Xldh...        27  0.921215
# 2350590  --Xpvc--Xfiller--Xfr--Xstabiliser--Xdinp--Xldh...        27  0.919943
# 2350591  --Xpvc--Xfiller--Xfr--Xstabiliser--Xdinp--Xldh...        27  0.922299
# 2350592  --Xpvc--Xfiller--Xfr--Xstabiliser--Xdinp--Xldh...        27  0.921382
# 2350593  --Xpvc--Xfiller--Xfr--Xstabiliser--Xdinp--Xldh...        27  0.919442
# 2350594  --Xpvc--Xfiller--Xfr--Xstabiliser--Xdinp--Xldh...        27  0.921724
# 2350595  --Xpvc--Xfiller--Xfr--Xstabiliser--Xdinp--Xldh...        27  0.916800
# 2350596  --Xpvc--Xfiller--Xfr--Xstabiliser--Xdinp--Xldh...        27  0.922870
# 2350597  --Xpvc--Xfiller--Xfr--Xstabiliser--Xdinp--Xldh...        27  0.921110
# 2350598  --Xpvc--Xfiller--Xfr--Xstabiliser--Xdinp--Xldh...        27  0.919639
# 2350599  --Xpvc--Xfiller--Xfr--Xstabiliser--Xdinp--Xldh...        27  0.922603
# 2350600  --Xpvc--Xfiller--Xfr--Xstabiliser--Xdinp--Xldh...        28  0.923218
#
# [2350601 rows x 7 columns]

# %%
count = np.zeros(28)
for i in model_df['No_terms']:
    count[i-1] += 1 
    
terms = np.linspace(1,28, 28)

# %%
Ylabel = 'Number of possible models ($10^{-3})$'
Xlabel = 'Model complexity'
FontSize = 12

plt.bar(terms, count/1000, edgecolor ='k', zorder = 3, width=0.75)
plt.axis([0, 26, 0 , 400])
plt.ylabel(Ylabel, fontsize=FontSize)
plt.xlabel(Xlabel, fontsize=FontSize)
# plt.tick_params(axis='x', labelsize=FontSize)
# plt.tick_params(axis='y', labelsize=FontSize)
plt.grid(axis = 'y', zorder = 0)
plt.tight_layout()
# plt.show()
plt.savefig('bar.png')

# %%
count = np.zeros(28)

for i, j in enumerate(model_df['Kfold']):
    k = model_df['No_terms'][i] - 1
    if count[k] < j:
        count[k] = j
    
terms = np.linspace(1,28, 28)

# %%
count2 = [100]*28

for i, j in enumerate(model_df['AIC']):
    k = model_df['No_terms'][i] - 1
    if count2[k] > j:
        count2[k] = j

# %%
count2
# Out:
# [47.42778347378051,
#  42.86732686549709,
#  19.9288247254094,
#  17.453302217943843,
#  17.262155503073274,
#  14.511872327928033,
#  13.586332479157178,
#  14.84886435486753,
#  13.58077896189188,
#  14.465871154863509,
#  15.485858220208184,
#  16.39663407314326,
#  16.871151402159587,
#  17.99163565729971,
#  18.902394498083037,
#  19.299660797472924,
#  20.529409018285502,
#  21.71622770375133,
#  22.42445091144761,
#  23.94080940236089,
#  25.59189889705506,
#  27.268026409402733,
#  28.7356436214247,
#  30.326904761636754,
#  31.953936886149663,
#  33.7418158621128,
#  35.628022471361064,
#  37.59934031662333]

# %%
min2 = 0
max2 = max(count2)

for i in range(len(count2)):
    count2[i] = 1- (count2[i]- min2)/(max2-min2)
count2
# Out:
# [0.0,
#  0.09615580308121663,
#  0.5798069556333653,
#  0.6320025744489504,
#  0.6360328432253995,
#  0.6940217048947559,
#  0.7135364235044189,
#  0.6869163332695818,
#  0.7136535176812608,
#  0.6949916252598928,
#  0.6734855165903078,
#  0.6542820922211596,
#  0.6442770425591055,
#  0.6206519820339902,
#  0.6014489163607478,
#  0.5930726805282319,
#  0.5671438234166104,
#  0.5421201221483035,
#  0.5271874570346616,
#  0.49521551190356417,
#  0.4604028056423294,
#  0.42506218059974676,
#  0.39411793010924456,
#  0.36056668601427744,
#  0.3262612218887532,
#  0.28856435214253096,
#  0.24879427496211592,
#  0.20722965395569515]

# %%
Ylabel = 'Number of possible models ($10^{-3})$'
Xlabel = 'Model complexity'
FontSize = 12

plt.plot(terms, count, "^")
plt.plot(terms, count2, "*")
plt.axis([0, 26, 0 , 1])
plt.ylabel(Ylabel, fontsize=FontSize)
plt.xlabel(Xlabel, fontsize=FontSize)
# plt.tick_params(axis='x', labelsize=FontSize)
# plt.tick_params(axis='y', labelsize=FontSize)
plt.grid(zorder = 0)
plt.tight_layout()
plt.show()
# plt.savefig('bar.png')

# %%
# plt.plot(model_df['No_terms'], model_df['r2'], 'r*')
# plt.plot(model_df['No_terms'], 1- (model_df['AIC']/80), 'b*')
# plt.plot(model_df['No_terms'], model_df['Kfold'], 'g*')
# plt.axis([0, 25, -0.5, 1.2])
# # plt.xlabel('CN')
# # plt.ylabel('AIC')
# plt.show()

# %%
# max(model_df['Kfold'])

# %%
# plt.plot(model_df['Cond_No'], model_df['Kfold'], 'r*')
# # plt.plot(model_df['No_terms'], 1- (model_df['AIC']/80), 'b*')
# # plt.plot(model_df['No_terms'], model_df['Kfold'], 'g*')
# plt.axis([0, 400, -1, 1])
# # plt.xlabel('CN')
# # plt.ylabel('AIC')
# plt.show()
